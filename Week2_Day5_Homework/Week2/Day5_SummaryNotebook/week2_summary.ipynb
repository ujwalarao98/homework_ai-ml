# %% [markdown]
# # Week 2 Summary Notebook\nReview of the NumPy and pandas concepts covered this week.

# %% [markdown]
# ## NumPy Arrays

# %%
import numpy as np\na = np.array([[1, 2, 3], [4, 5, 6]])\nprint(a)\nprint('Shape:', a.shape)\nprint('Size:', a.size)\nprint('Dimensions:', a.ndim)

# %% [markdown]
# ## NumPy Reshape, Flatten, Math, and Statistics

# %%
values = np.arange(1, 13)\nmatrix = values.reshape(3, 4)\nprint(matrix)\nprint(matrix.flatten())\nprint('Mean:', np.mean(values))\nprint('Median:', np.median(values))\nprint('Standard deviation:', np.std(values))

# %% [markdown]
# ## pandas Series and DataFrames

# %%
import pandas as pd\nseries = pd.Series([85, 92, 78], index=['Aarav', 'Diya', 'Ishaan'])\nprint(series)\n\ndf = pd.DataFrame({\n    'Name': ['Aarav', 'Diya', 'Ishaan'],\n    'Score': [85, 92, 78]\n})\nprint(df)

# %% [markdown]
# ## pandas Filtering, Missing Values, New Columns, and GroupBy

# %%
df = pd.DataFrame({\n    'Name': ['Aarav', 'Diya', 'Ishaan', 'Meera'],\n    'Department': ['IT', 'HR', 'IT', 'HR'],\n    'Score': [85, 92, None, 88]\n})\ndf['Score'] = df['Score'].fillna(df['Score'].mean())\ndf['Passed'] = df['Score'] >= 80\nprint(df[df['Score'] >= 85])\nprint(df.groupby('Department')['Score'].mean())

# %% [markdown]
# ## Key Learnings\n- NumPy arrays, shape, size, ndim\n- Indexing and slicing\n- Reshape and flatten\n- Array math and statistics\n- pandas Series and DataFrames\n- CSV reading and inspection\n- Filtering rows and selecting columns\n- Missing-value handling\n- Renaming and sorting\n- Creating calculated columns\n- GroupBy summaries
